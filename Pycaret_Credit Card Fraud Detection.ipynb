# %% [markdown]
# # <center>Credit Card Anomaly Detection Using Pycaret

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading CSV file into dataframe
from pycaret.classification import *
df = pd.read_csv('/content/drive/MyDrive/Tao Digital USA/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
len(df[df['Class']==0])
# Out:
# 284315

# %%
len(df[df['Class']==1])
# Out:
# 492

# %%
# Importing module and Initialize the setup
from pycaret.classification import *
clf = setup(data = df, target = 'Class')
# Out:
# <style  type="text/css" >
# #T_098861fa_c6b6_11ec_bb02_4edfac07bb3arow44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_098861fa_c6b6_11ec_bb02_4edfac07bb3a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_098861fa_c6b6_11ec_bb02_4edfac07bb3alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_098861fa_c6b6_11ec_bb02_4edfac07bb3arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_098861fa_c6b6_11ec_bb02_4edfac07bb3arow0_col1" class="data row0 col1" >7283</td>
#             </tr>
#             <tr>
#                         <th id="T_098861fa_c6b6_11ec_bb02_4edfac07bb3alevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
# Compare with all models availale in Pycaret
compare_models()
# Out:
# <style  type="text/css" >
#     #T_553250da_c6bd_11ec_94ff_4edfac07bb3a th {
#           text-align: left;
# ...

# %%
# Change the Sort Order with F1 Score
best = compare_models(sort = 'F1')
# Out:
# <style  type="text/css" >
#     #T_c6a2aacc_c6c6_11ec_80ac_4edfac07bb3a th {
#           text-align: left;
# ...

# %%
print(best)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=7283, verbose=0,
#                        warm_start=False)

# %%
# Creating the model
RandomForest = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col0,#T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col1,#T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col2,#T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col3,#T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col4,#T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col5,#T_745093e2_c6bf_11ec_a9ad_4edfac07bb3arow10_col6{
#             background:  yellow;
# ...
